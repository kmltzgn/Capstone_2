# %% [markdown]
# # Data Wrangling
#
# In this notebook, we clean the house data to make it ready for EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
pd.set_option("max_columns" , 100)
pd.set_option("display.max_rows", 100)
pd.options.display.max_columns = 100

# %%
house_data = pd.read_csv('train.csv')

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
house_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
house_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
# See the percentage of missing data

missing_data = pd.concat([house_data.isnull().sum(), 100 * house_data.isnull().mean()], axis=1)
missing_data.columns=['count', '%']
missing_data.sort_values(by='count', ascending = True)
# Out:
#                count          %
# Id                 0   0.000000
# TotalBsmtSF        0   0.000000
# Heating            0   0.000000
# SaleCondition      0   0.000000
# CentralAir         0   0.000000
# 1stFlrSF           0   0.000000
# 2ndFlrSF           0   0.000000
# LowQualFinSF       0   0.000000
# GrLivArea          0   0.000000
# BsmtFullBath       0   0.000000
# BsmtHalfBath       0   0.000000
# FullBath           0   0.000000
# HalfBath           0   0.000000
# BedroomAbvGr       0   0.000000
# KitchenAbvGr       0   0.000000
# KitchenQual        0   0.000000
# TotRmsAbvGrd       0   0.000000
# Functional         0   0.000000
# SaleType           0   0.000000
# YrSold             0   0.000000
# MoSold             0   0.000000
# MiscVal            0   0.000000
# PoolArea           0   0.000000
# ScreenPorch        0   0.000000
# BsmtUnfSF          0   0.000000
# 3SsnPorch          0   0.000000
# OpenPorchSF        0   0.000000
# WoodDeckSF         0   0.000000
# ...

# %%
# List the categorical features

print(len(house_data.select_dtypes('object').columns))

house_data.select_dtypes('object')
# Out:
# 43
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
# ...

# %%
categorical_feature_names = house_data.select_dtypes('object').columns

print(categorical_feature_names)

print(len(categorical_feature_names))
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')
# 43

# %%
df_categorical = house_data[categorical_feature_names] 

df_categorical
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
# ...

# %%
# List the numerical features

print(len(house_data.select_dtypes('number').columns))

house_data.select_dtypes('number')
# Out:
# 38
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %%
numerical_feature_names = house_data.select_dtypes('number').columns

print(numerical_feature_names)

print(len(numerical_feature_names))
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')
# 38

# %%
df_numerical = house_data[numerical_feature_names] 

df_numerical
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %%
house_data.describe(include = 'all')
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %%
# Let us look at the distribution of the Sale Price, our target feature   

house_data.SalePrice.hist(bins=30)
plt.xlabel('SalePrice')
plt.ylabel('Count')
plt.title('Distribution of sale prices');

# %%
# Now let us take a look at the distribution of all numerical features 

house_data.hist(figsize=(18, 12))
plt.subplots_adjust(hspace=0.5);

# %%
# An integer value is assigned to the feature "MoSold", which refers to the month sold. Let us convert it to categorical data.

import calendar

house_data['MoSold'] = house_data['MoSold'].apply(lambda i: calendar.month_name[i])

house_data['MoSold']
# Out:
# 0        February
# 1             May
# 2       September
# 3        February
# 4        December
#           ...
# 1455       August
# 1456     February
# 1457          May
# 1458        April
# 1459         June
# Name: MoSold, Length: 1460, dtype: object

# %%
# Now let us check whether the feature "MoSold" disappeared from the numerical features 

house_data.hist(figsize=(18, 12))
plt.subplots_adjust(hspace=0.5);

# %%
def plot_countplot_3(feature1, feature2, feature3, dataframe):
    
    plt.figure(figsize=(18, 6))  
    
    plt.subplot(1,3,1) 
    plt1 = sns.countplot(x=dataframe[feature1], data=dataframe)
    
    plt.subplot(1,3,2) 
    plt2 = sns.countplot(x=dataframe[feature2], data=dataframe)
    
    plt.subplot(1,3,3) 
    plt3 = sns.countplot(x=dataframe[feature3], data=dataframe)
    
    plt.show()

# %%
# Now let us take a look at the distribution of all categorical features 

plot_countplot_3('MSZoning', 'Street', 'Alley', house_data)
plot_countplot_3('LotShape', 'LandContour', 'Utilities', house_data)
plot_countplot_3('LotConfig', 'LandSlope', 'SaleCondition', house_data)
plot_countplot_3('HouseStyle', 'RoofStyle', 'RoofMatl', house_data)
plot_countplot_3('ExterQual', 'ExterCond', 'Foundation', house_data)

plot_countplot_3('BsmtQual', 'BsmtCond', 'BsmtExposure', house_data)
plot_countplot_3('BsmtFinType1','BsmtFinType2','Heating', house_data)
plot_countplot_3('HeatingQC', 'CentralAir', 'Electrical', house_data)
plot_countplot_3('KitchenQual', 'Functional', 'FireplaceQu', house_data)
plot_countplot_3('GarageType', 'GarageFinish', 'GarageQual', house_data)
plot_countplot_3('GarageCond', 'PavedDrive', 'PoolQC', house_data)

plot_countplot_3('Fence', 'MiscFeature','SaleType', house_data)

# %%
sns.countplot(x='MasVnrType', data=house_data)
# Out:
# <AxesSubplot:xlabel='MasVnrType', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(27,9)})

sns.countplot(x='MoSold', data=house_data)
# Out:
# <AxesSubplot:xlabel='MoSold', ylabel='count'>

# %%
sns.countplot(x='Neighborhood', data=house_data)
# Out:
# <AxesSubplot:xlabel='Neighborhood', ylabel='count'>

# %%
sns.countplot(x='Exterior1st', data=house_data)
# Out:
# <AxesSubplot:xlabel='Exterior1st', ylabel='count'>

# %%
sns.countplot(x='Exterior2nd', data=house_data)
# Out:
# <AxesSubplot:xlabel='Exterior2nd', ylabel='count'>

# %% [markdown]
# Okay, nothing is suspicious for the categorical features at this stage. We'll save the data and move to EDA

# %% [markdown]
# ## Save data

# %%
house_data.shape
# Out:
# (1460, 81)

# %%
# writing into the file

house_data.to_csv("house_data_DW.csv", index=False)
